# %% [markdown]
# # **⚡ SAM Algorithm**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **🧮 Intermolecular Potential**

# %%
# Lennard-Jones potential between all pairs
def intermolecular_pair_potential(coordinates, epsilon=1.0, sigma=1.0):
    total_energy = 0.0
    n = len(coordinates)
    for i in range(n - 1):
        for j in range(i + 1, n):
            r = np.linalg.norm(coordinates[i] - coordinates[j])
            # Avoid division by zero or too small r
            if r == 0:
                continue
            total_energy += 4 * epsilon * ((sigma / r) ** 12 - (sigma / r) ** 6)
    return total_energy

# %% [markdown]
# ## **🧬 Annealing Lennard-Jones**

# %%
def adaptive_simulated_annealing_lj(initial_coords, epsilon=1.0, sigma=1.0, 
                                    initial_step=0.05, initial_temp=10, max_iter_factor=2000):
    n_particles = initial_coords.shape[0]
    max_iterations = max_iter_factor * n_particles

    coords = initial_coords.copy()
    current_energy = intermolecular_pair_potential(coords, epsilon, sigma)
    best_coords = coords.copy()
    best_energy = current_energy

    T = initial_temp
    step_size = initial_step
    accept_count = 0
    adapt_interval = 1000  # how often to adapt step size and temperature

    for iteration in range(1, max_iterations + 1):
        # Propose new coords by adding Gaussian noise scaled by current step size
        proposal = coords + np.random.normal(scale=step_size, size=coords.shape)
        proposal_energy = intermolecular_pair_potential(proposal, epsilon, sigma)

        if proposal_energy < current_energy:
            # Accept only improvements
            coords = proposal
            current_energy = proposal_energy
            accept_count += 1

            # Update best if improved
            if current_energy < best_energy:
                best_energy = current_energy
                best_coords = coords.copy()

        # Adapt step size and temperature every adapt_interval iterations
        if iteration % adapt_interval == 0:
            acceptance_rate = accept_count / adapt_interval
            accept_count = 0

            # Adapt step size: if acceptance rate is too low, reduce step size; if too high, increase
            if acceptance_rate < 0.2:
                step_size *= 0.9
            elif acceptance_rate > 0.5:
                step_size *= 1.1

            # Decrease temperature adaptively
            T *= 0.9

            print(f"Iter {iteration:6d} | Temp {T:.5f} | Step size {step_size:.5f} | Best Energy {best_energy:.5f} | Acceptance Rate {acceptance_rate:.3f}")

        # Optional stopping criterion if step size becomes very small
        if step_size < 1e-5:
            print("Step size too small, stopping optimization.")
            break

    print(f"Best energy found: {best_energy:.5f}")
    return best_coords, best_energy

# %% [markdown]
# ## **🧪 Testing**

# %%
# Example usage
initial_coords = np.random.rand(38, 3)  # 10 particles in 3D

optimized_coords, final_energy = adaptive_simulated_annealing_lj(initial_coords)

print("Optimized Coordinates:\n", optimized_coords)
print("Final Potential Energy:", final_energy)
# Out:
# Iter   1000 | Temp 9.00000 | Step size 0.04500 | Best Energy 511669621.35766 | Acceptance Rate 0.017
# Iter   2000 | Temp 8.10000 | Step size 0.04050 | Best Energy 39359528.72915 | Acceptance Rate 0.011
# Iter   3000 | Temp 7.29000 | Step size 0.03645 | Best Energy 35937465.41382 | Acceptance Rate 0.002
# Iter   4000 | Temp 6.56100 | Step size 0.03281 | Best Energy 3726623.44093 | Acceptance Rate 0.016
# Iter   5000 | Temp 5.90490 | Step size 0.02952 | Best Energy 766449.79496 | Acceptance Rate 0.019
# Iter   6000 | Temp 5.31441 | Step size 0.02657 | Best Energy 174787.95611 | Acceptance Rate 0.025
# Iter   7000 | Temp 4.78297 | Step size 0.02391 | Best Energy 6623.20538 | Acceptance Rate 0.059
# Iter   8000 | Temp 4.30467 | Step size 0.02152 | Best Energy 41.61441 | Acceptance Rate 0.078
# Iter   9000 | Temp 3.87420 | Step size 0.01937 | Best Energy -116.48547 | Acceptance Rate 0.048
# Iter  10000 | Temp 3.48678 | Step size 0.01743 | Best Energy -131.27138 | Acceptance Rate 0.023
# Iter  11000 | Temp 3.13811 | Step size 0.01569 | Best Energy -136.89599 | Acceptance Rate 0.012
# Iter  12000 | Temp 2.82430 | Step size 0.01412 | Best Energy -139.93418 | Acceptance Rate 0.013
# Iter  13000 | Temp 2.54187 | Step size 0.01271 | Best Energy -143.82578 | Acceptance Rate 0.021
# Iter  14000 | Temp 2.28768 | Step size 0.01144 | Best Energy -145.96616 | Acceptance Rate 0.012
# Iter  15000 | Temp 2.05891 | Step size 0.01029 | Best Energy -148.87034 | Acceptance Rate 0.013
# Iter  16000 | Temp 1.85302 | Step size 0.00927 | Best Energy -150.01208 | Acceptance Rate 0.009
# Iter  17000 | Temp 1.66772 | Step size 0.00834 | Best Energy -150.92466 | Acceptance Rate 0.012
# Iter  18000 | Temp 1.50095 | Step size 0.00750 | Best Energy -152.27033 | Acceptance Rate 0.014
# Iter  19000 | Temp 1.35085 | Step size 0.00675 | Best Energy -152.67067 | Acceptance Rate 0.010
# Iter  20000 | Temp 1.21577 | Step size 0.00608 | Best Energy -153.37627 | Acceptance Rate 0.016
# Iter  21000 | Temp 1.09419 | Step size 0.00547 | Best Energy -153.77947 | Acceptance Rate 0.009
# Iter  22000 | Temp 0.98477 | Step size 0.00492 | Best Energy -154.60020 | Acceptance Rate 0.018
# Iter  23000 | Temp 0.88629 | Step size 0.00443 | Best Energy -155.37858 | Acceptance Rate 0.014
# Iter  24000 | Temp 0.79766 | Step size 0.00399 | Best Energy -155.86014 | Acceptance Rate 0.013
# Iter  25000 | Temp 0.71790 | Step size 0.00359 | Best Energy -156.26497 | Acceptance Rate 0.014
# Iter  26000 | Temp 0.64611 | Step size 0.00323 | Best Energy -156.70458 | Acceptance Rate 0.022
# Iter  27000 | Temp 0.58150 | Step size 0.00291 | Best Energy -157.01836 | Acceptance Rate 0.020
# Iter  28000 | Temp 0.52335 | Step size 0.00262 | Best Energy -157.57388 | Acceptance Rate 0.039
# Iter  29000 | Temp 0.47101 | Step size 0.00236 | Best Energy -158.12114 | Acceptance Rate 0.038
# Iter  30000 | Temp 0.42391 | Step size 0.00212 | Best Energy -158.47514 | Acceptance Rate 0.034
# Iter  31000 | Temp 0.38152 | Step size 0.00191 | Best Energy -159.08343 | Acceptance Rate 0.052
# Iter  32000 | Temp 0.34337 | Step size 0.00172 | Best Energy -159.66041 | Acceptance Rate 0.054
# Iter  33000 | Temp 0.30903 | Step size 0.00155 | Best Energy -160.30496 | Acceptance Rate 0.078
# Iter  34000 | Temp 0.27813 | Step size 0.00139 | Best Energy -160.80372 | Acceptance Rate 0.072
# Iter  35000 | Temp 0.25032 | Step size 0.00125 | Best Energy -161.33191 | Acceptance Rate 0.088
# Iter  36000 | Temp 0.22528 | Step size 0.00113 | Best Energy -161.94357 | Acceptance Rate 0.111
# Iter  37000 | Temp 0.20276 | Step size 0.00101 | Best Energy -162.64363 | Acceptance Rate 0.137
# Iter  38000 | Temp 0.18248 | Step size 0.00091 | Best Energy -163.62640 | Acceptance Rate 0.162
# Iter  39000 | Temp 0.16423 | Step size 0.00082 | Best Energy -164.29044 | Acceptance Rate 0.150
# Iter  40000 | Temp 0.14781 | Step size 0.00074 | Best Energy -164.62236 | Acceptance Rate 0.118
# Iter  41000 | Temp 0.13303 | Step size 0.00067 | Best Energy -164.92412 | Acceptance Rate 0.126
# Iter  42000 | Temp 0.11973 | Step size 0.00060 | Best Energy -165.08118 | Acceptance Rate 0.096
# Iter  43000 | Temp 0.10775 | Step size 0.00054 | Best Energy -165.27364 | Acceptance Rate 0.132
# Iter  44000 | Temp 0.09698 | Step size 0.00048 | Best Energy -165.41950 | Acceptance Rate 0.119
# Iter  45000 | Temp 0.08728 | Step size 0.00044 | Best Energy -165.51818 | Acceptance Rate 0.106
# Iter  46000 | Temp 0.07855 | Step size 0.00039 | Best Energy -165.61439 | Acceptance Rate 0.125
# Iter  47000 | Temp 0.07070 | Step size 0.00035 | Best Energy -165.67414 | Acceptance Rate 0.081
# Iter  48000 | Temp 0.06363 | Step size 0.00032 | Best Energy -165.71533 | Acceptance Rate 0.088
# Iter  49000 | Temp 0.05726 | Step size 0.00029 | Best Energy -165.74689 | Acceptance Rate 0.104
# Iter  50000 | Temp 0.05154 | Step size 0.00026 | Best Energy -165.77467 | Acceptance Rate 0.097
# Iter  51000 | Temp 0.04638 | Step size 0.00023 | Best Energy -165.80363 | Acceptance Rate 0.108
# Iter  52000 | Temp 0.04175 | Step size 0.00021 | Best Energy -165.82663 | Acceptance Rate 0.094
# Iter  53000 | Temp 0.03757 | Step size 0.00019 | Best Energy -165.84962 | Acceptance Rate 0.123
# Iter  54000 | Temp 0.03381 | Step size 0.00017 | Best Energy -165.87526 | Acceptance Rate 0.142
# Iter  55000 | Temp 0.03043 | Step size 0.00015 | Best Energy -165.90924 | Acceptance Rate 0.189
# Iter  56000 | Temp 0.02739 | Step size 0.00015 | Best Energy -165.94900 | Acceptance Rate 0.221
# Iter  57000 | Temp 0.02465 | Step size 0.00015 | Best Energy -165.99078 | Acceptance Rate 0.228
# Iter  58000 | Temp 0.02219 | Step size 0.00015 | Best Energy -166.04375 | Acceptance Rate 0.253
# Iter  59000 | Temp 0.01997 | Step size 0.00015 | Best Energy -166.10450 | Acceptance Rate 0.272
# Iter  60000 | Temp 0.01797 | Step size 0.00015 | Best Energy -166.16367 | Acceptance Rate 0.259
# Iter  61000 | Temp 0.01617 | Step size 0.00015 | Best Energy -166.22627 | Acceptance Rate 0.256
# Iter  62000 | Temp 0.01456 | Step size 0.00015 | Best Energy -166.31179 | Acceptance Rate 0.309
# Iter  63000 | Temp 0.01310 | Step size 0.00015 | Best Energy -166.39250 | Acceptance Rate 0.289
# Iter  64000 | Temp 0.01179 | Step size 0.00015 | Best Energy -166.48153 | Acceptance Rate 0.308
# Iter  65000 | Temp 0.01061 | Step size 0.00015 | Best Energy -166.56466 | Acceptance Rate 0.280
# Iter  66000 | Temp 0.00955 | Step size 0.00015 | Best Energy -166.65932 | Acceptance Rate 0.304
# Iter  67000 | Temp 0.00860 | Step size 0.00015 | Best Energy -166.75827 | Acceptance Rate 0.311
# Iter  68000 | Temp 0.00774 | Step size 0.00015 | Best Energy -166.86672 | Acceptance Rate 0.322
# Iter  69000 | Temp 0.00696 | Step size 0.00015 | Best Energy -166.97012 | Acceptance Rate 0.316
# Iter  70000 | Temp 0.00627 | Step size 0.00015 | Best Energy -167.06055 | Acceptance Rate 0.298
# Iter  71000 | Temp 0.00564 | Step size 0.00015 | Best Energy -167.16296 | Acceptance Rate 0.317
# Iter  72000 | Temp 0.00508 | Step size 0.00015 | Best Energy -167.26745 | Acceptance Rate 0.301
# Iter  73000 | Temp 0.00457 | Step size 0.00015 | Best Energy -167.38651 | Acceptance Rate 0.329
# Iter  74000 | Temp 0.00411 | Step size 0.00015 | Best Energy -167.51657 | Acceptance Rate 0.337
# Iter  75000 | Temp 0.00370 | Step size 0.00015 | Best Energy -167.64723 | Acceptance Rate 0.337
# Iter  76000 | Temp 0.00333 | Step size 0.00015 | Best Energy -167.80670 | Acceptance Rate 0.374
# Best energy found: -167.80670
# Optimized Coordinates:
#  [[ 1.51426387 -0.64825279  0.81784248]
#  [-1.31943784  1.1546325  -0.61612144]
#  [-0.79961612  0.57727561  1.12812819]
#  [ 0.18797852  0.9117657   0.80371257]
#  [ 0.43444268  1.85287589  0.30716275]
#  [-0.622098   -0.83078867  0.01921193]
#  [ 1.902795   -0.46880046 -0.21679927]
#  [ 1.17037188  1.04516017  0.40728055]
#  [ 2.1289151   1.32588821  0.00356629]
#  [-1.08291928 -0.01898385 -0.63980325]
#  [ 1.93919822  0.05509926  1.60394888]
#  [-0.32613609  1.64233484 -0.43719233]
#  [-0.18976218 -1.50188883  0.77523274]
#  [ 0.68666255  0.52620226 -1.24821561]
#  [ 1.73601513  1.10563041  1.31746205]
#  [ 0.987899   -0.29996319  2.05545753]
#  [ 0.04686872  0.16011825  1.64010835]
#  [-1.56924705  1.00647075  0.45487004]
#  [ 0.39015538  0.83540788 -0.26785579]
#  [ 1.51883668  2.04339456  0.59371608]
#  [ 1.1257346   1.59765961 -0.53556124]
#  [ 0.48958157 -0.74408631  1.1784277 ]
#  [ 0.02806137 -0.14690861 -0.55445395]
#  [-0.6063983   0.6745047   0.04674126]
#  [-0.38647858  0.73767661 -1.06047344]
#  [-0.03182878 -0.07723663  0.52832242]
#  [ 1.02440474 -0.46098339 -0.87120553]
#  [ 0.78210783  1.65177577  1.32395648]
#  [-0.62763919  1.59890802  0.65143444]
#  [ 1.54718032  0.56384599 -0.54762899]
#  [-0.67267762 -0.58885668  1.20827064]
#  [ 0.99023519  0.26644536  1.12497271]
#  [ 0.49743692 -0.96760883  0.07048842]
#  [-1.30216016 -0.08766772  0.43893397]
#  [ 0.95016987 -0.00562913  0.1115531 ]
#  [-0.1704879   1.25882267  1.75642683]
#  [ 1.95389908  0.33246953  0.5257467 ]
#  [ 0.86177859  0.82143003  2.031283  ]]
# Final Potential Energy: -167.80669652169698
